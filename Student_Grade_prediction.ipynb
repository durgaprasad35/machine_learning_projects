# %%
#Importing the neccessary libraries 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %%
#Importing the data set 
df = pd.read_csv(r"C:\Users\HP\Downloads\student-mat.csv")

# %%
df.head()
# Out:
#   school sex  age address famsize Parrent_status  Mother_edu  Father_edu  \
# 0     GP   F   18       U     GT3              A           4           4
# 1     GP   F   17       U     GT3              T           1           1
# 2     GP   F   15       U     LE3              T           1           1
# 3     GP   F   15       U     GT3              T           4           2
# 4     GP   F   16       U     GT3              T           3           3
#
#   Mother_job Father_job  ... Family_quality_reln freetime_after_school  \
# 0    at_home    teacher  ...                   4                     3
# 1    at_home      other  ...                   5                     3
# 2    at_home      other  ...                   4                     3
# 3     health   services  ...                   3                     2
# 4      other      other  ...                   4                     3
#
#    goout_with_friends  workday_alcohol_consum  weekend_alcohol_consum  \
# ...

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Parrent_status',
#        'Mother_edu', 'Father_edu', 'Mother_job', 'Father_job',
#        'reason_to_chose_school', 'guardian', 'traveltime', 'weekly_studytime',
#        'failures', 'extra_edu_supp', 'family_edu_supp', 'extra_paid_class',
#        'extra_curr_activities', 'nursery', 'Interested_in_higher_edu',
#        'internet_access', 'romantic_relationship', 'Family_quality_reln',
#        'freetime_after_school', 'goout_with_friends', 'workday_alcohol_consum',
#        'weekend_alcohol_consum', 'health_status', 'absences', 'G1', 'G2',
#        'G3'],
#       dtype='object')

# %%
df.drop(['address','famsize','reason_to_chose_school','extra_edu_supp','family_edu_supp','Interested_in_higher_edu','romantic_relationship','weekend_alcohol_consum','workday_alcohol_consum'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'Parrent_status', 'Mother_edu', 'Father_edu',
#        'Mother_job', 'Father_job', 'guardian', 'traveltime',
#        'weekly_studytime', 'failures', 'extra_paid_class',
#        'extra_curr_activities', 'nursery', 'internet_access',
#        'Family_quality_reln', 'freetime_after_school', 'goout_with_friends',
#        'health_status', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.head()
# Out:
#   school sex  age Parrent_status  Mother_edu  Father_edu Mother_job  \
# 0     GP   F   18              A           4           4    at_home
# 1     GP   F   17              T           1           1    at_home
# 2     GP   F   15              T           1           1    at_home
# 3     GP   F   15              T           4           2     health
# 4     GP   F   16              T           3           3      other
#
#   Father_job guardian  traveltime  ...  nursery  internet_access  \
# 0    teacher   mother           2  ...      yes               no
# 1      other   father           1  ...       no              yes
# 2      other   mother           1  ...      yes              yes
# 3   services   mother           1  ...      yes              yes
# 4      other   father           1  ...      yes               no
#
#   Family_quality_reln freetime_after_school goout_with_friends health_status  \
# 0                   4                     3                  4             3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   school                 395 non-null    object
#  1   sex                    395 non-null    object
#  2   age                    395 non-null    int64
#  3   Parrent_status         395 non-null    object
#  4   Mother_edu             395 non-null    int64
#  5   Father_edu             395 non-null    int64
#  6   Mother_job             395 non-null    object
#  7   Father_job             395 non-null    object
#  8   guardian               395 non-null    object
#  9   traveltime             395 non-null    int64
#  10  weekly_studytime       395 non-null    int64
#  11  failures               395 non-null    int64
#  12  extra_paid_class       395 non-null    object
#  13  extra_curr_activities  395 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# school                   0
# sex                      0
# age                      0
# Parrent_status           0
# Mother_edu               0
# Father_edu               0
# Mother_job               0
# Father_job               0
# guardian                 0
# traveltime               0
# weekly_studytime         0
# failures                 0
# extra_paid_class         0
# extra_curr_activities    0
# nursery                  0
# internet_access          0
# Family_quality_reln      0
# freetime_after_school    0
# goout_with_friends       0
# health_status            0
# absences                 0
# G1                       0
# G2                       0
# G3                       0
# dtype: int64

# %%
df.dtypes
# Out:
# school                   object
# sex                      object
# age                       int64
# Parrent_status           object
# Mother_edu                int64
# Father_edu                int64
# Mother_job               object
# Father_job               object
# guardian                 object
# traveltime                int64
# weekly_studytime          int64
# failures                  int64
# extra_paid_class         object
# extra_curr_activities    object
# nursery                  object
# internet_access          object
# Family_quality_reln       int64
# freetime_after_school     int64
# goout_with_friends        int64
# health_status             int64
# absences                  int64
# G1                        int64
# G2                        int64
# G3                        int64
# dtype: object

# %%
#Checking the unique elements in the school column 
df['school'].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
#Assigning the numerical value to the unique elements in the school column 
df['school'] = df['school'].map({'GP':0,'MS':1})

# %%
df['school'].dtype
# Out:
# dtype('int64')

# %%
df['sex'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['sex'] = df['sex'].map({'F':0,'M':1})

# %%
df['Parrent_status'].unique()
# Out:
# array(['A', 'T'], dtype=object)

# %%
df['Parrent_status'] = df['Parrent_status'].map({'A':0,'T':1})

# %%
df['Mother_job'].unique()
# Out:
# array(['at_home', 'health', 'other', 'services', 'teacher'], dtype=object)

# %%
df['Mother_job'] = df['Mother_job'].map({'at_home':0,'health':1,'services':2,'teacher':3,'other':4})

# %%
df['Father_job'].unique()
# Out:
# array(['teacher', 'other', 'services', 'health', 'at_home'], dtype=object)

# %%
df['Father_job'] = df['Father_job'].map({'at_home':0,'health':1,'services':2,'teacher':3,'other':4})

# %%
df['guardian'].unique()
# Out:
# array(['mother', 'father', 'other'], dtype=object)

# %%
df['guardian'] = df['guardian'].str.strip().str.lower()
df['guardian'] = df['guardian'].map({'mother':0, 'father':1, 'other':2})

# %%
df['extra_paid_class'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['extra_paid_class'] = df['extra_paid_class'].map({'no':0,'yes':1})

# %%
df['extra_curr_activities'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['extra_curr_activities'] = df['extra_curr_activities'].map({'no':0,'yes':1})

# %%
df['nursery'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df['nursery'] = df['nursery'].map({'no':0,'yes':1})

# %%
df['internet_access'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['internet_access'] = df['internet_access'].map({'no':0,'yes':1})

# %%
df.dtypes
# Out:
# school                   int64
# sex                      int64
# age                      int64
# Parrent_status           int64
# Mother_edu               int64
# Father_edu               int64
# Mother_job               int64
# Father_job               int64
# guardian                 int64
# traveltime               int64
# weekly_studytime         int64
# failures                 int64
# extra_paid_class         int64
# extra_curr_activities    int64
# nursery                  int64
# internet_access          int64
# Family_quality_reln      int64
# freetime_after_school    int64
# goout_with_friends       int64
# health_status            int64
# absences                 int64
# G1                       int64
# G2                       int64
# G3                       int64
# dtype: object

# %%
corr_matrix = df.corr()

# Step 2: Plot correlation heatmap
plt.figure(figsize=(15, 10))
plt.imshow(corr_matrix, interpolation='nearest')  # no color specified (default used)
plt.colorbar()

# Put ticks and labels
plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns, rotation=45)
plt.yticks(range(len(corr_matrix.columns)), corr_matrix.columns)

plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'Parrent_status', 'Mother_edu', 'Father_edu',
#        'Mother_job', 'Father_job', 'guardian', 'traveltime',
#        'weekly_studytime', 'failures', 'extra_paid_class',
#        'extra_curr_activities', 'nursery', 'internet_access',
#        'Family_quality_reln', 'freetime_after_school', 'goout_with_friends',
#        'health_status', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df['G1'].unique()
# Out:
# array([ 5,  7, 15,  6, 12, 16, 14, 10, 13,  8, 11,  9, 17, 19, 18,  4,  3])

# %%
df['goout_with_friends'].unique()
# Out:
# array([4, 3, 2, 1, 5])

# %%
df['freetime_after_school'].unique()
# Out:
# array([3, 2, 4, 1, 5])

# %%
df['guardian']
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 390    2
# 391    0
# 392    2
# 393    0
# 394    1
# Name: guardian, Length: 395, dtype: int64

# %%
X = df.iloc[:,:-1] 
y = df.iloc[:,-1] 
X
# Out:
#      school  sex       age  Parrent_status  Mother_edu  Father_edu  \
# 0         0    0  2.944439               0    1.609438    1.609438
# 1         0    0  2.890372               1    0.693147    0.693147
# 2         0    0  2.772589               1    0.693147    0.693147
# 3         0    0  2.772589               1    1.609438    1.098612
# 4         0    0  2.833213               1    1.386294    1.386294
# ..      ...  ...       ...             ...         ...         ...
# 390       1    1  3.044522               0    1.098612    1.098612
# 391       1    1  2.890372               1    1.386294    0.693147
# 392       1    1  3.091042               1    0.693147    0.693147
# 393       1    1  2.944439               1    1.386294    1.098612
# 394       1    1  2.995732               1    0.693147    0.693147
#
#      Mother_job  Father_job  guardian  traveltime  ...  extra_curr_activities  \
# 0             0           3         0           2  ...                      0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model1 = LinearRegression()

# %%
model1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score , mean_squared_error

# %%
y_pred = model1.predict(X_test)

# %%
y_pred
# Out:
# array([ 6.01422359, 12.19713567,  3.5735974 ,  9.35679266,  8.67879463,
#        11.97662078, 18.61151684,  8.21109132,  6.51770767, 12.2587631 ,
#        14.83255581,  6.15716385, 13.15163484, 11.48996054, 15.08258544,
#         8.04008104,  6.74849761, 11.349489  , 14.26263051,  7.52608543,
#        14.60397551, 16.20961239, 14.39923695,  5.15563039,  6.51087436,
#        20.6131465 , 10.81792553,  8.85210844, 16.02370791, 11.21722996,
#         8.82986084,  7.7776339 , 14.40572395, 12.57613922,  5.76114121,
#         5.34031112, -2.94640066, 14.75439516, 12.30864639,  7.5307424 ,
#         5.52221044,  9.99797048, 14.75677736,  7.18419506, 16.63217273,
#         9.14242317, 11.96427099, 13.86196554, 11.74518429, 16.46736287,
#        13.92887   , 14.04185276, 10.77942917,  8.12223677,  4.16775331,
#        12.9418465 , 10.54021817,  6.53003095, 14.99007449, 15.74712973,
#        13.14488951,  8.52352216,  7.79160579,  3.88647595,  4.03112888,
# ...

# %%
r2_score(y_pred,y_test)
# Out:
# 0.7968399040260464

# %%
mean_squared_error(y_pred,y_test)
# Out:
# 3.9791427860779676

# %%
y_test.min()
# Out:
# np.int64(0)

# %%
y_test.max()
# Out:
# np.int64(19)

# %%
df.hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'school'}>,
#         <Axes: title={'center': 'sex'}>, <Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'Parrent_status'}>,
#         <Axes: title={'center': 'Mother_edu'}>],
#        [<Axes: title={'center': 'Father_edu'}>,
#         <Axes: title={'center': 'Mother_job'}>,
#         <Axes: title={'center': 'Father_job'}>,
#         <Axes: title={'center': 'guardian'}>,
#         <Axes: title={'center': 'traveltime'}>],
#        [<Axes: title={'center': 'weekly_studytime'}>,
#         <Axes: title={'center': 'failures'}>,
#         <Axes: title={'center': 'extra_paid_class'}>,
#         <Axes: title={'center': 'extra_curr_activities'}>,
#         <Axes: title={'center': 'nursery'}>],
#        [<Axes: title={'center': 'internet_access'}>,
#         <Axes: title={'center': 'Family_quality_reln'}>,
#         <Axes: title={'center': 'freetime_after_school'}>,
#         <Axes: title={'center': 'goout_with_friends'}>,
# ...

# %%
#
df['absences'] = np.log(df['absences']+1)

# %%
df.hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'school'}>,
#         <Axes: title={'center': 'sex'}>, <Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'Parrent_status'}>,
#         <Axes: title={'center': 'Mother_edu'}>],
#        [<Axes: title={'center': 'Father_edu'}>,
#         <Axes: title={'center': 'Mother_job'}>,
#         <Axes: title={'center': 'Father_job'}>,
#         <Axes: title={'center': 'guardian'}>,
#         <Axes: title={'center': 'traveltime'}>],
#        [<Axes: title={'center': 'weekly_studytime'}>,
#         <Axes: title={'center': 'failures'}>,
#         <Axes: title={'center': 'extra_paid_class'}>,
#         <Axes: title={'center': 'extra_curr_activities'}>,
#         <Axes: title={'center': 'nursery'}>],
#        [<Axes: title={'center': 'internet_access'}>,
#         <Axes: title={'center': 'Family_quality_reln'}>,
#         <Axes: title={'center': 'freetime_after_school'}>,
#         <Axes: title={'center': 'goout_with_friends'}>,
# ...

# %%
df['age'] = np.log(df['age']+1)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'Parrent_status', 'Mother_edu', 'Father_edu',
#        'Mother_job', 'Father_job', 'guardian', 'traveltime',
#        'weekly_studytime', 'failures', 'extra_paid_class',
#        'extra_curr_activities', 'nursery', 'internet_access',
#        'Family_quality_reln', 'freetime_after_school', 'goout_with_friends',
#        'health_status', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df['Mother_edu'] = np.log(df['Mother_edu']+1) 
df['Father_edu'] = np.log(df['Father_edu']+1)

# %%
df.hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'school'}>,
#         <Axes: title={'center': 'sex'}>, <Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'Parrent_status'}>,
#         <Axes: title={'center': 'Mother_edu'}>],
#        [<Axes: title={'center': 'Father_edu'}>,
#         <Axes: title={'center': 'Mother_job'}>,
#         <Axes: title={'center': 'Father_job'}>,
#         <Axes: title={'center': 'guardian'}>,
#         <Axes: title={'center': 'traveltime'}>],
#        [<Axes: title={'center': 'weekly_studytime'}>,
#         <Axes: title={'center': 'failures'}>,
#         <Axes: title={'center': 'extra_paid_class'}>,
#         <Axes: title={'center': 'extra_curr_activities'}>,
#         <Axes: title={'center': 'nursery'}>],
#        [<Axes: title={'center': 'internet_access'}>,
#         <Axes: title={'center': 'Family_quality_reln'}>,
#         <Axes: title={'center': 'freetime_after_school'}>,
#         <Axes: title={'center': 'goout_with_friends'}>,
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model2 = RandomForestRegressor()

# %%
model2.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred2 = model2.predict(X_test)

# %%
str(round(r2_score(y_pred2,y_test)*100))+"%"
# Out:
# '85%'

# %%
mean_squared_error(y_pred2,y_test)
# Out:
# 2.5965618320610684

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model3 = DecisionTreeRegressor()

# %%
model3.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred3 = model3.predict(X_test)

# %%
r2_score(y_pred3,y_test)
# Out:
# 0.7480797897156382

# %%
mean_squared_error(y_pred3,y_test)
# Out:
# 5.1603053435114505

# %% [markdown]
# OUT OF THREE MODELS WE SELECTED THE RANDOMFORESTREGRESSOR PERFORMING GOOD WITH R2_SCORE 85% AND LOW MEAN_SQUARED_ERROR
