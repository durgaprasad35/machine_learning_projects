# %%
#Importing the neccessary libraries 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %%
#Importing the training dataset 
train_df = pd.read_excel(r"C:\Users\HP\Downloads\Data_Train.xlsx")

# %%
train_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
#importing the test data 
test_data = pd.read_excel(r"C:\Users\HP\Downloads\Test_set.xlsx")

# %%
test_data.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
#Now we can join the train and test data 
final_df = pd.concat([train_df,test_data])

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %%
#Checking how many null values are there in columns 
final_df.isnull().sum()
# Out:
# Airline               0
# Date_of_Journey       0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# dtype: int64

# %%
#WE can apply the feature engineering on the 'Date_of_Journey' 
final_df['Date'] = final_df['Date_of_Journey'].str.split('/').str[0]

# %%
final_df['Month'] = final_df['Date_of_Journey'].str.split('/').str[1]

# %%
final_df['Year'] = final_df['Date_of_Journey'].str.split('/').str[2]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  object
#  12  Month            13354 non-null  object
#  13  Year             13354 non-null  object
# dtypes: float64(1), object(13)
# memory usage: 1.5+ MB

# %%
#Changing the datatypes of the 'Date','Month' and 'Year' 
final_df['Date'] = final_df['Date'].astype(int) 
final_df['Month'] = final_df['Month'].astype(int)
final_df['Year'] = final_df['Year'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  int64
#  12  Month            13354 non-null  int64
#  13  Year             13354 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 1.5+ MB

# %%
#Now we can drop the 'Date_of_Journey' column 
final_df.drop('Date_of_Journey',axis=1,inplace=True)

# %%
final_df.head(1)
# Out:
#   Airline    Source Destination      Route Dep_Time  Arrival_Time Duration  \
# 0  IndiGo  Banglore   New Delhi  BLR → DEL    22:20  01:10 22 Mar   2h 50m
#
#   Total_Stops Additional_Info   Price  Date  Month  Year
# 0    non-stop         No info  3897.0    24      3  2019

# %%
#Now lets move to the 'Arrival_TIme' column 
final_df['Time'] = final_df['Arrival_Time'].str.split(' ').str[0]

# %%
final_df['arrival_hour'] = final_df['Time'].str.split(':').str[0] 
final_df['arrival_hour']
# Out:
# 0       01
# 1       13
# 2       04
# 3       23
# 4       21
#         ..
# 2666    20
# 2667    16
# 2668    04
# 2669    19
# 2670    19
# Name: arrival_hour, Length: 13354, dtype: object

# %%
final_df['Arrival_minutes'] = final_df['Time'].str.split(':').str[1] 
final_df['Arrival_minutes']
# Out:
# 0       10
# 1       15
# 2       25
# 3       30
# 4       35
#         ..
# 2666    25
# 2667    55
# 2668    25
# 2669    15
# 2670    15
# Name: Arrival_minutes, Length: 13354, dtype: object

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  Date             13354 non-null  int64
#  11  Month            13354 non-null  int64
#  12  Year             13354 non-null  int64
#  13  Time             13354 non-null  object
#  14  arrival_hour     13354 non-null  object
#  15  Arrival_minutes  13354 non-null  object
# dtypes: float64(1), int64(3), object(12)
# ...

# %%
final_df.drop('Time',axis=1,inplace=True)

# %%
final_df['arrival_hour'] = final_df['arrival_hour'].astype(int) 
final_df['Arrival_minutes'] = final_df['Arrival_minutes'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  Date             13354 non-null  int64
#  11  Month            13354 non-null  int64
#  12  Year             13354 non-null  int64
#  13  arrival_hour     13354 non-null  int64
#  14  Arrival_minutes  13354 non-null  int64
# dtypes: float64(1), int64(5), object(9)
# memory usage: 1.6+ MB

# %%
#Now we can drop the Arrival_Time column 
final_df.drop('Arrival_Time',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Total_Stops Additional_Info    Price  Date  Month  Year  arrival_hour  \
# 0    non-stop         No info   3897.0    24      3  2019             1
# 1     2 stops         No info   7662.0     1      5  2019            13
# 2     2 stops         No info  13882.0     9      6  2019             4
# 3      1 stop         No info   6218.0    12      5  2019            23
# 4      1 stop         No info  13302.0     1      3  2019            21
#
#    Arrival_minutes
# 0               10
# 1               15
# ...

# %%
final_df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
#Mapping the 'Total_Stops' values to numerical values 
final_df['Total_Stops'] = final_df['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4,'nan':2})

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#    Total_Stops Additional_Info    Price  Date  Month  Year  arrival_hour  \
# 0          0.0         No info   3897.0    24      3  2019             1
# 1          2.0         No info   7662.0     1      5  2019            13
# 2          2.0         No info  13882.0     9      6  2019             4
# 3          1.0         No info   6218.0    12      5  2019            23
# 4          1.0         No info  13302.0     1      3  2019            21
#
#    Arrival_minutes
# 0               10
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Duration         13354 non-null  object
#  6   Total_Stops      13353 non-null  float64
#  7   Additional_Info  13354 non-null  object
#  8   Price            10683 non-null  float64
#  9   Date             13354 non-null  int64
#  10  Month            13354 non-null  int64
#  11  Year             13354 non-null  int64
#  12  arrival_hour     13354 non-null  int64
#  13  Arrival_minutes  13354 non-null  int64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.5+ MB

# %%
#Dropping the Route column 
final_df.drop('Route',axis=1,inplace=True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination Dep_Time Duration  Total_Stops  \
# 0       IndiGo  Banglore   New Delhi    22:20   2h 50m          0.0
# 1    Air India   Kolkata    Banglore    05:50   7h 25m          2.0
# 2  Jet Airways     Delhi      Cochin    09:25      19h          2.0
# 3       IndiGo   Kolkata    Banglore    18:05   5h 25m          1.0
# 4       IndiGo  Banglore   New Delhi    16:50   4h 45m          1.0
#
#   Additional_Info    Price  Date  Month  Year  arrival_hour  Arrival_minutes
# 0         No info   3897.0    24      3  2019             1               10
# 1         No info   7662.0     1      5  2019            13               15
# 2         No info  13882.0     9      6  2019             4               25
# 3         No info   6218.0    12      5  2019            23               30
# 4         No info  13302.0     1      3  2019            21               35

# %%
final_df['Dep_Hour'] = final_df['Dep_Time'].str.split(':').str[0] 
final_df['Dep_Minute'] = final_df['Dep_Time'].str.split(':').str[1]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Dep_Time         13354 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  float64
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   Date             13354 non-null  int64
#  9   Month            13354 non-null  int64
#  10  Year             13354 non-null  int64
#  11  arrival_hour     13354 non-null  int64
#  12  Arrival_minutes  13354 non-null  int64
#  13  Dep_Hour         13354 non-null  object
#  14  Dep_Minute       13354 non-null  object
# dtypes: float64(2), int64(5), object(8)
# memory usage: 1.6+ MB

# %%
final_df['Dep_Hour'] = final_df['Dep_Hour'].astype(int) 
final_df['Dep_Minute'] = final_df['Dep_Minute'].astype(int)

# %%
final_df.head()
# Out:
#        Airline    Source Destination Dep_Time Duration  Total_Stops  \
# 0       IndiGo  Banglore   New Delhi    22:20   2h 50m          0.0
# 1    Air India   Kolkata    Banglore    05:50   7h 25m          2.0
# 2  Jet Airways     Delhi      Cochin    09:25      19h          2.0
# 3       IndiGo   Kolkata    Banglore    18:05   5h 25m          1.0
# 4       IndiGo  Banglore   New Delhi    16:50   4h 45m          1.0
#
#   Additional_Info    Price  Date  Month  Year  arrival_hour  Arrival_minutes  \
# 0         No info   3897.0    24      3  2019             1               10
# 1         No info   7662.0     1      5  2019            13               15
# 2         No info  13882.0     9      6  2019             4               25
# 3         No info   6218.0    12      5  2019            23               30
# 4         No info  13302.0     1      3  2019            21               35
#
#    Dep_Hour  Dep_Minute
# 0        22          20
# 1         5          50
# ...

# %%
#Droping the 'Dep_Time' column 
final_df.drop('Dep_Time',axis=1,inplace=True)

# %%
final_df.head(1)
# Out:
#   Airline    Source Destination Duration  Total_Stops Additional_Info   Price  \
# 0  IndiGo  Banglore   New Delhi   2h 50m          0.0         No info  3897.0
#
#    Date  Month  Year  arrival_hour  Arrival_minutes  Dep_Hour  Dep_Minute
# 0    24      3  2019             1               10        22          20

# %%
final_df['Duration_Hour'] = final_df['Duration'].str.split('h').str[0] 
final_df['Duration_Hour']
# Out:
# 0        2
# 1        7
# 2       19
# 3        5
# 4        4
#         ..
# 2666    23
# 2667     2
# 2668     6
# 2669    15
# 2670    14
# Name: Duration_Hour, Length: 13354, dtype: object

# %%
final_df['Duration_minutes'] = final_df['Duration'].str.split('h').str[1] 
final_df['Duration_minutes'] = final_df['Duration_minutes'].str.replace('m','')

# %%
final_df['Duration_minutes']
# Out:
# 0        50
# 1        25
# 2
# 3        25
# 4        45
#        ...
# 2666     55
# 2667     35
# 2668     35
# 2669     15
# 2670     20
# Name: Duration_minutes, Length: 13354, dtype: object

# %%
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          2.0         No info
# 2  Jet Airways     Delhi      Cochin      19h          2.0         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  Date  Month  Year  arrival_hour  Arrival_minutes  Dep_Hour  \
# 0   3897.0    24      3  2019             1               10        22
# 1   7662.0     1      5  2019            13               15         5
# 2  13882.0     9      6  2019             4               25         9
# 3   6218.0    12      5  2019            23               30        18
# 4  13302.0     1      3  2019            21               35        16
#
#    Dep_Minute Duration_Hour Duration_minutes
# ...

# %%
#Dropping the 'Duration' column 
final_df.drop('Duration',axis=1,inplace=True)

# %%
final_df.head(1)
# Out:
#   Airline    Source Destination  Total_Stops Additional_Info   Price  Date  \
# 0  IndiGo  Banglore   New Delhi          0.0         No info  3897.0    24
#
#    Month  Year  arrival_hour  Arrival_minutes  Dep_Hour  Dep_Minute  \
# 0      3  2019             1               10        22          20
#
#   Duration_Hour Duration_minutes
# 0             2               50

# %%
#Now we can do the label encoding for the 'Airline','Source','Destination' and 'Additional_Info' 
from sklearn.preprocessing import LabelEncoder 
le = LabelEncoder()

# %%
final_df['Airline']  = le.fit_transform(final_df['Airline'])

# %%
final_df['Source'] = le.fit_transform(final_df['Source']) 
final_df['Destination'] = le.fit_transform(final_df['Destination']) 
final_df['Additional_Info'] = le.fit_transform(final_df['Additional_Info'])

# %%
final_df.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info    Price  Date  \
# 0        3       0            5          0.0                8   3897.0    24
# 1        1       3            0          2.0                8   7662.0     1
# 2        4       2            1          2.0                8  13882.0     9
# 3        3       3            0          1.0                8   6218.0    12
# 4        3       0            5          1.0                8  13302.0     1
#
#    Month  Year  arrival_hour  Arrival_minutes  Dep_Hour  Dep_Minute  \
# 0      3  2019             1               10        22          20
# 1      5  2019            13               15         5          50
# 2      6  2019             4               25         9          25
# 3      5  2019            23               30        18           5
# 4      3  2019            21               35        16          50
#
#   Duration_Hour Duration_minutes
# 0             2               50
# ...

# %% [markdown]
# NOW THE DATA IS READY FOR TRAINING THE MODEL

# %%
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import RandomForestRegressor

# %%
X = final_df.drop(['Price'],axis=1)
y = np.log1p(final_df['Price'])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=42)

# %%
from sklearn.pipeline import Pipeline 
from sklearn.preprocessing import StandardScaler

# %%
reg = RandomForestRegressor()

# %%
reg.fit(X_train,y_train) 
reg.score(X_train,y_train)
# Out:
# 0.9502978747597622

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score 
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("MAE:", mae)
print("RMSE:", rmse)
print("R²:", r2)
# Out:
# MAE: 0.18031494221838443
# RMSE: 0.06780114721173902
# R²: 0.6828556135206955

# %%
final_df[final_df['Duration_Hour']=='5m']
# Out:
#       Airline  Source  Destination  Total_Stops  Additional_Info    Price  \
# 6474        1       4            3          2.0                8  17327.0
# 2660        1       4            3          2.0                8      NaN
#
#       Date  Month  Year  arrival_hour  Arrival_minutes  Dep_Hour  Dep_Minute  \
# 6474     6      3  2019            16               55        16          50
# 2660    12      3  2019            16               55        16          50
#
#      Duration_Hour Duration_minutes
# 6474            5m              NaN
# 2660            5m              NaN

# %%
final_df.drop(index=[6474,2660],inplace=True)

# %%
final_df[final_df['Duration_Hour']=='5m']
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Total_Stops, Additional_Info, Price, Date, Month, Year, arrival_hour, Arrival_minutes, Dep_Hour, Dep_Minute, Duration_Hour, Duration_minutes]
# Index: []

# %%
final_df.drop(['Duration_minutes'],axis=1,inplace=True)

# %%
final_df['Price'] = final_df['Price'].fillna(final_df['Price'].median())

# %%
final_df['Price'].mean()
# Out:
# np.float64(8943.129877911766)

# %%
y = np.log1p(final_df['Price'])
