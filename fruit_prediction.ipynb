# %%
#Importing the neccassary libraries 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %%
#Importing the dataset 
df = pd.read_csv(r"C:\Users\HP\Downloads\fruit_classification_dataset.csv")

# %%
df.head()
# Out:
#    size (cm)  shape  weight (g)  avg_price (₹)   color  taste     fruit_name
# 0       25.4  round      3089.2          137.1   green  sweet     watermelon
# 1       24.6  round      3283.9          163.8   green  sweet     watermelon
# 2        7.8  round       319.0           91.3   green  sweet  custard apple
# 3       20.0   oval      1607.0           85.7  orange  sweet         papaya
# 4       10.2   long       131.5           37.8  yellow  sweet         banana

# %%
df.isna().sum()
# Out:
# size (cm)        0
# shape            0
# weight (g)       0
# avg_price (₹)    0
# color            0
# taste            0
# fruit_name       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
df['shape'].unique()
# Out:
# array(['round', 'oval', 'long'], dtype=object)

# %%
df['shape'] = df['shape'].map({'round':0 , 'oval':1,'long':2})

# %%
df['color'].unique()
# Out:
# array(['green', 'orange', 'yellow', 'red', 'purple', 'blue', 'brown',
#        'pink'], dtype=object)

# %%
df['color'] = df['color'].map({'green':0,'orange':1,'yellow':2,'red':3,'purple':4,'blue':5,'brown':6,'pink':7})

# %%
df['taste'].unique()
# Out:
# array(['sweet', 'tangy', 'sour'], dtype=object)

# %%
df['taste'] = df['taste'].map({'sweet':0,'tangy':1,'sour':2})

# %%
X = df.iloc[:,:-1] 
y = le.fit_transform(df['fruit_name'])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier() 
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test) 
actual_pred = le.inverse_transform(y_pred)

# %%
model.score(X_train,y_train)
# Out:
# 1.0

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
from sklearn.model_selection import RandomizedSearchCV
# Parameter grid
param_dist = {
    'n_estimators': [100, 200, 300, 500],
    'max_depth': [None, 5, 10, 20, 30, 50],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 4, 5],
    'max_features': ['sqrt', 'log2', None],
    'bootstrap': [True, False]
}

# Model
rf = RandomForestClassifier()

# Randomized Search
random_search = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_dist,
    n_iter=30,               # number of combinations to try
    cv=5,                    # 5-fold cross validation
    scoring='accuracy',
    n_jobs=-1,               # use all CPUs
    verbose=2,
    random_state=42
)

random_search.fit(X, y)

print("Best Parameters:", random_search.best_params_)
print("Best Score:", random_search.best_score_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best Parameters: {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 10, 'bootstrap': False}
# Best Score: 1.0

# %%
best_model = random_search.best_estimator_
best_model.fit(X_train, y_train)
pred = best_model.predict(X_test)
decoded_pred = le.inverse_transform(pred)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
cm = confusion_matrix(pred,y_test)

# %%
classification_report(pred,y_test)
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00        99\n           1       1.00      1.00      1.00       103\n           2       1.00      1.00      1.00       116\n           3       1.00      1.00      1.00        89\n           4       1.00      1.00      1.00       111\n           5       1.00      1.00      1.00        99\n           6       1.00      1.00      1.00        96\n           7       1.00      1.00      1.00       115\n           8       1.00      1.00      1.00        84\n           9       1.00      1.00      1.00        96\n          10       1.00      1.00      1.00       107\n          11       1.00      1.00      1.00        87\n          12       1.00      1.00      1.00        89\n          13       1.00      1.00      1.00        96\n          14       1.00      1.00      1.00       106\n          15       1.00      1.00      1.00        93\n          16       1.00      1.00      1.00       104\n     
# ...
